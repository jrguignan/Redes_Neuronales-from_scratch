# %%
#Codigo en keras que permite comprobar las redes echas a mano
import numpy as np
import matplotlib.pyplot as plt
import random
#import warnings
#Para quitar un warnings+-
from IPython.display import display, HTML

import tensorflow as tf
import tensorflow.keras as kr



#Se construyen los parametros de entrada y de salida
#Generacion de los datos
X =np.array(np.linspace(-4, 4, 20000))
X = X[:,np.newaxis]
#Pendiente (m), Corte en Y(b), Valores de Y sin ruido(_Y)
m , b = 0.5, 1
_Y = np.sin(b +m*X)
#Genera el ruido en los valores de _Y
Y=[]
for i in range(len(X)):
   ax = _Y[i] + ( (-1)**( (i%2)+2) )   *0.1*random.random()
   Y.append(ax)

Y=np.array(Y)


learning_rate = 0.01           # learning rate
nn = [20,3,1]  # número de neuronas por capa.


# Creamos el objeto que contendrá a nuestra red neuronal, como
# secuencia de capas.
model = kr.Sequential()

# Añadimos la capa 1
l1 = model.add(kr.layers.Dense(nn[0], activation='sigmoid'))

# Añadimos la capa 2
l2 = model.add(kr.layers.Dense(nn[1], activation='sigmoid'))

# Añadimos la capa 3
l3 = model.add(kr.layers.Dense(nn[2], activation='sigmoid'))

# Añadimos la capa 4
#l4 = model.add(kr.layers.Dense(nn[3], activation='sigmoid'))


# Compilamos el modelo, definiendo la función de coste y el optimizador.
model.compile(loss='mse', optimizer=kr.optimizers.SGD(learning_rate=0.05), metrics=['acc'])


# Y entrenamos al modelo. Los callbacks
model.fit(X, Y, epochs=100)

y = model.predict(X)


#Graficas de los puntos originales y los de la red neuronal
fig = plt.figure(figsize=(10,7))
plt.title("Grafica de Puntos Originales y los de la Red Neuronal")
plt.plot(X,_Y, color='red')
plt.scatter(X,Y)
plt.scatter(X,y)
plt.legend(["Grafica original","Puntos Entrenamiento","Puntos Red N."])
plt.show()
# Out:
# WARNING:tensorflow:From c:\Users\jrgui\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\jrgui\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\jrgui\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\jrgui\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 625/625 [==============================] - 3s 2ms/step - loss: 0.2643 - acc: 0.0000e+00
# Epoch 2/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1799 - acc: 0.0000e+00
# Epoch 3/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1393 - acc: 0.0000e+00
# Epoch 4/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1248 - acc: 0.0000e+00
# Epoch 5/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1182 - acc: 0.0000e+00
# Epoch 6/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1145 - acc: 0.0000e+00
# Epoch 7/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1122 - acc: 0.0000e+00
# Epoch 8/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1106 - acc: 0.0000e+00
# Epoch 9/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1094 - acc: 0.0000e+00
# Epoch 10/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1085 - acc: 0.0000e+00
# Epoch 11/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1078 - acc: 0.0000e+00
# Epoch 12/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1073 - acc: 0.0000e+00
# Epoch 13/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.1068 - acc: 0.0000e+00
# Epoch 14/100
# 625/625 [==============================] - 2s 2ms/step - loss: 0.1063 - acc: 0.0000e+00
# Epoch 15/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1058 - acc: 0.0000e+00
# Epoch 16/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1054 - acc: 0.0000e+00
# Epoch 17/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1049 - acc: 0.0000e+00
# Epoch 18/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.1043 - acc: 0.0000e+00
# Epoch 19/100
# 625/625 [==============================] - 2s 2ms/step - loss: 0.1038 - acc: 0.0000e+00
# Epoch 20/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1032 - acc: 0.0000e+00
# Epoch 21/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1026 - acc: 0.0000e+00
# Epoch 22/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1020 - acc: 0.0000e+00
# Epoch 23/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.1014 - acc: 0.0000e+00
# Epoch 24/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.1007 - acc: 0.0000e+00
# Epoch 25/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.1000 - acc: 0.0000e+00
# Epoch 26/100
# 625/625 [==============================] - 2s 2ms/step - loss: 0.0992 - acc: 0.0000e+00
# Epoch 27/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0984 - acc: 0.0000e+00
# Epoch 28/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0975 - acc: 0.0000e+00
# Epoch 29/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0965 - acc: 0.0000e+00
# Epoch 30/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0955 - acc: 0.0000e+00
# Epoch 31/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0945 - acc: 0.0000e+00
# Epoch 32/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.